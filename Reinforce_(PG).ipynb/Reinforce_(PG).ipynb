# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheksuran/Atari_DQN/blob/master/Reinforce_(PG).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import gym 
import tensorflow_probability as tfp

# %%
# import tensorflow_probability as tfp

# %%
# !pip3 install box2d-py
# Out:
# Collecting box2d-py
#   Downloading https://files.pythonhosted.org/packages/06/bd/6cdc3fd994b0649dcf5d9bad85bd9e26172308bbe9a421bfc6fdbf5081a6/box2d_py-2.3.8-cp36-cp36m-manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 8.0MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %%
env= gym.make("CartPole-v0")
low = env.observation_space.low
high = env.observation_space.high
env.action_space
# Out:
# Discrete(2)

# %%
env.reset()
# Out:
# array([ 0.03267921, -0.00591846, -0.02706212,  0.04254023], dtype=float32)

# %%
class model(tf.keras.Model):
  def __init__(self):
    super().__init__()
    self.d1 = tf.keras.layers.Dense(30,activation='relu')
    self.d2 = tf.keras.layers.Dense(30,activation='relu')
    self.out = tf.keras.layers.Dense(2,activation='softmax')

  def call(self, input_data):
    x = tf.convert_to_tensor(input_data)
#     print(x.shape)
    x = self.d1(x)
    x = self.d2(x)
    x = self.out(x)
    return x

  def action_value(self, state):
        p = self.predict(state)
        return p

# %%
class agent():
  def __init__(self):
    self.model = model()
    self.opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    self.gamma = 1

  def act(self,state):
    prob = self.model(np.array([state]))
    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
    action = dist.sample()
#     print(int(action.numpy()[0]))
    return int(action.numpy()[0])

  def a_loss(self,prob, action, reward): 
#     print(prob, action, reward)
    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
    log_prob = dist.log_prob(action)
    loss = -log_prob*reward
    return loss 

  def train(self, states, rewards, actions):
    sum_reward = 0
    discnt_rewards = []
    rewards.reverse()
    for r in rewards:
      sum_reward = r + self.gamma*sum_reward
      discnt_rewards.append(sum_reward)
    discnt_rewards.reverse()  

    for state, reward, action in zip(states, discnt_rewards, actions):
      with tf.GradientTape() as tape:
        p = self.model(np.array([state]), training=True)
        loss = self.a_loss(p, action, reward)
      grads = tape.gradient(loss, self.model.trainable_variables)
      self.opt.apply_gradients(zip(grads, self.model.trainable_variables))

# %%
agentoo7 = agent()
steps = 500
for s in range(steps):
  
  done = False
  state = env.reset()
  total_reward = 0
  rewards = []
  states = []
  actions = []
  while not done:
    #env.render()
    action = agentoo7.act(state)
    #print(action)
    next_state, reward, done, _ = env.step(action)
    rewards.append(reward)
    states.append(state)
    actions.append(action)
    state = next_state
    total_reward += reward
    
    if done:
      agentoo7.train(states, rewards, actions)
      #print("total step for this episord are {}".format(t))
      print("total reward after {} steps is {}".format(s, total_reward))
# Out:
# total reward after 0 steps is 16.0
# total reward after 1 steps is 16.0
# total reward after 2 steps is 16.0
# total reward after 3 steps is 13.0
# total reward after 4 steps is 15.0
# total reward after 5 steps is 22.0
# total reward after 6 steps is 25.0
# total reward after 7 steps is 15.0
# total reward after 8 steps is 38.0
# total reward after 9 steps is 12.0
# total reward after 10 steps is 30.0
# total reward after 11 steps is 37.0
# total reward after 12 steps is 29.0
# total reward after 13 steps is 17.0
# total reward after 14 steps is 16.0
# total reward after 15 steps is 9.0
# total reward after 16 steps is 58.0
# total reward after 17 steps is 83.0
# total reward after 18 steps is 30.0
# total reward after 19 steps is 43.0
# total reward after 20 steps is 19.0
# total reward after 21 steps is 57.0
# total reward after 22 steps is 44.0
# total reward after 23 steps is 20.0
# total reward after 24 steps is 37.0
# total reward after 25 steps is 16.0
# total reward after 26 steps is 52.0
# total reward after 27 steps is 82.0
# total reward after 28 steps is 45.0
# total reward after 29 steps is 33.0
# total reward after 30 steps is 85.0
# total reward after 31 steps is 44.0
# total reward after 32 steps is 44.0
# total reward after 33 steps is 63.0
# total reward after 34 steps is 86.0
# total reward after 35 steps is 60.0
# total reward after 36 steps is 125.0
# total reward after 37 steps is 52.0
# total reward after 38 steps is 45.0
# total reward after 39 steps is 99.0
# total reward after 40 steps is 93.0
# total reward after 41 steps is 86.0
# total reward after 42 steps is 83.0
# total reward after 43 steps is 83.0
# total reward after 44 steps is 65.0
# total reward after 45 steps is 98.0
# total reward after 46 steps is 145.0
# total reward after 47 steps is 181.0
# total reward after 48 steps is 54.0
# total reward after 49 steps is 28.0
# total reward after 50 steps is 73.0
# total reward after 51 steps is 81.0
# total reward after 52 steps is 200.0
# total reward after 53 steps is 124.0
# total reward after 54 steps is 200.0
# total reward after 55 steps is 200.0
# total reward after 56 steps is 170.0
# total reward after 57 steps is 186.0
# total reward after 58 steps is 145.0
# total reward after 59 steps is 167.0
# total reward after 60 steps is 163.0
# total reward after 61 steps is 183.0
# total reward after 62 steps is 200.0
# total reward after 63 steps is 200.0
# total reward after 64 steps is 133.0
# total reward after 65 steps is 163.0
# total reward after 66 steps is 200.0
# total reward after 67 steps is 200.0
# total reward after 68 steps is 200.0
# total reward after 69 steps is 200.0
# total reward after 70 steps is 22.0
# total reward after 71 steps is 91.0
# total reward after 72 steps is 200.0
# total reward after 73 steps is 45.0
# total reward after 74 steps is 198.0
# total reward after 75 steps is 200.0
# total reward after 76 steps is 200.0
# total reward after 77 steps is 200.0
# total reward after 78 steps is 200.0
# total reward after 79 steps is 200.0
# total reward after 80 steps is 200.0
# total reward after 81 steps is 200.0
# total reward after 82 steps is 200.0
# total reward after 83 steps is 200.0
# total reward after 84 steps is 200.0
# total reward after 85 steps is 200.0
# total reward after 86 steps is 186.0
# total reward after 87 steps is 200.0
# total reward after 88 steps is 200.0
# total reward after 89 steps is 200.0
# total reward after 90 steps is 200.0
# total reward after 91 steps is 200.0
# total reward after 92 steps is 200.0
# total reward after 93 steps is 200.0
# total reward after 94 steps is 200.0
# total reward after 95 steps is 185.0
# total reward after 96 steps is 200.0
# total reward after 97 steps is 200.0
# total reward after 98 steps is 200.0
# total reward after 99 steps is 39.0
# total reward after 100 steps is 200.0
# total reward after 101 steps is 200.0
# total reward after 102 steps is 200.0
# total reward after 103 steps is 200.0
# total reward after 104 steps is 200.0
# total reward after 105 steps is 200.0
# total reward after 106 steps is 200.0
# total reward after 107 steps is 30.0
# total reward after 108 steps is 200.0
# total reward after 109 steps is 200.0
# total reward after 110 steps is 200.0
# total reward after 111 steps is 200.0
# total reward after 112 steps is 200.0
# total reward after 113 steps is 200.0
# total reward after 114 steps is 200.0
# total reward after 115 steps is 200.0
# total reward after 116 steps is 200.0
# total reward after 117 steps is 200.0
# total reward after 118 steps is 100.0
# total reward after 119 steps is 67.0
# total reward after 120 steps is 80.0
# total reward after 121 steps is 71.0
# total reward after 122 steps is 131.0
# total reward after 123 steps is 79.0
# total reward after 124 steps is 176.0
# total reward after 125 steps is 90.0
# total reward after 126 steps is 89.0
# total reward after 127 steps is 200.0
# total reward after 128 steps is 200.0
# total reward after 129 steps is 83.0
# total reward after 130 steps is 166.0
# total reward after 131 steps is 200.0
# total reward after 132 steps is 200.0
# total reward after 133 steps is 200.0
# total reward after 134 steps is 127.0
# total reward after 135 steps is 200.0
# total reward after 136 steps is 200.0
# total reward after 137 steps is 200.0
# total reward after 138 steps is 200.0
# total reward after 139 steps is 53.0
# total reward after 140 steps is 200.0
# total reward after 141 steps is 200.0
# total reward after 142 steps is 34.0
# total reward after 143 steps is 200.0
# total reward after 144 steps is 200.0
# total reward after 145 steps is 200.0
# total reward after 146 steps is 200.0
# total reward after 147 steps is 200.0
# total reward after 148 steps is 200.0
# total reward after 149 steps is 119.0
# total reward after 150 steps is 200.0
# total reward after 151 steps is 194.0
# total reward after 152 steps is 194.0
# total reward after 153 steps is 193.0
# total reward after 154 steps is 124.0
# total reward after 155 steps is 92.0
# total reward after 156 steps is 200.0
# total reward after 157 steps is 200.0
# total reward after 158 steps is 50.0
# total reward after 159 steps is 200.0
# total reward after 160 steps is 30.0
# total reward after 161 steps is 200.0
# total reward after 162 steps is 200.0
# total reward after 163 steps is 49.0
# total reward after 164 steps is 200.0
# total reward after 165 steps is 200.0
# total reward after 166 steps is 200.0
# total reward after 167 steps is 200.0
# total reward after 168 steps is 200.0
# total reward after 169 steps is 200.0
# total reward after 170 steps is 200.0
# total reward after 171 steps is 200.0
# total reward after 172 steps is 200.0
# total reward after 173 steps is 200.0
# total reward after 174 steps is 200.0
# total reward after 175 steps is 200.0
# total reward after 176 steps is 39.0
# total reward after 177 steps is 187.0
# total reward after 178 steps is 116.0
# total reward after 179 steps is 126.0
# total reward after 180 steps is 138.0
# total reward after 181 steps is 115.0
# total reward after 182 steps is 36.0
# total reward after 183 steps is 108.0
# total reward after 184 steps is 20.0
# total reward after 185 steps is 67.0
# total reward after 186 steps is 200.0
# total reward after 187 steps is 160.0
# total reward after 188 steps is 200.0
# total reward after 189 steps is 200.0
# total reward after 190 steps is 200.0
# total reward after 191 steps is 200.0
# total reward after 192 steps is 130.0
# total reward after 193 steps is 200.0
# total reward after 194 steps is 38.0
# total reward after 195 steps is 200.0
# total reward after 196 steps is 200.0
# total reward after 197 steps is 200.0
# total reward after 198 steps is 200.0
# total reward after 199 steps is 177.0
# total reward after 200 steps is 200.0
# total reward after 201 steps is 200.0
# total reward after 202 steps is 41.0
# total reward after 203 steps is 200.0
# total reward after 204 steps is 200.0
# total reward after 205 steps is 180.0
# total reward after 206 steps is 200.0
# total reward after 207 steps is 200.0
# total reward after 208 steps is 200.0
# total reward after 209 steps is 200.0
# total reward after 210 steps is 143.0
# total reward after 211 steps is 200.0
# total reward after 212 steps is 161.0
# total reward after 213 steps is 200.0
# total reward after 214 steps is 107.0
# total reward after 215 steps is 13.0
# total reward after 216 steps is 200.0
# total reward after 217 steps is 120.0
# total reward after 218 steps is 170.0
# total reward after 219 steps is 200.0
# total reward after 220 steps is 163.0
# total reward after 221 steps is 200.0
# total reward after 222 steps is 200.0
# total reward after 223 steps is 200.0
# total reward after 224 steps is 159.0
# total reward after 225 steps is 200.0
# total reward after 226 steps is 200.0
# total reward after 227 steps is 187.0
# total reward after 228 steps is 119.0
# total reward after 229 steps is 200.0
# total reward after 230 steps is 150.0
# total reward after 231 steps is 106.0
# total reward after 232 steps is 192.0
# total reward after 233 steps is 169.0
# total reward after 234 steps is 130.0
# total reward after 235 steps is 176.0
# total reward after 236 steps is 142.0
# total reward after 237 steps is 34.0
# total reward after 238 steps is 74.0
# total reward after 239 steps is 200.0
# total reward after 240 steps is 91.0
# total reward after 241 steps is 53.0
# total reward after 242 steps is 200.0
# total reward after 243 steps is 29.0
# total reward after 244 steps is 61.0
# total reward after 245 steps is 200.0
# total reward after 246 steps is 200.0
# total reward after 247 steps is 200.0
# total reward after 248 steps is 200.0
# total reward after 249 steps is 200.0
# total reward after 250 steps is 200.0
# total reward after 251 steps is 153.0
# total reward after 252 steps is 200.0
# total reward after 253 steps is 200.0
# total reward after 254 steps is 200.0
# total reward after 255 steps is 200.0
# total reward after 256 steps is 200.0
# total reward after 257 steps is 200.0
# total reward after 258 steps is 200.0
# total reward after 259 steps is 200.0
# total reward after 260 steps is 200.0
# total reward after 261 steps is 200.0
# total reward after 262 steps is 200.0
# total reward after 263 steps is 200.0
# total reward after 264 steps is 200.0
# total reward after 265 steps is 200.0
# total reward after 266 steps is 200.0
# total reward after 267 steps is 55.0
# total reward after 268 steps is 200.0
# total reward after 269 steps is 74.0
# total reward after 270 steps is 108.0
# total reward after 271 steps is 140.0
# total reward after 272 steps is 55.0
# total reward after 273 steps is 200.0
# total reward after 274 steps is 54.0
# total reward after 275 steps is 32.0
# total reward after 276 steps is 92.0
# total reward after 277 steps is 144.0
# total reward after 278 steps is 77.0
# total reward after 279 steps is 33.0
# total reward after 280 steps is 103.0
# total reward after 281 steps is 24.0
# total reward after 282 steps is 200.0
# total reward after 283 steps is 200.0
# total reward after 284 steps is 200.0
# total reward after 285 steps is 200.0
# total reward after 286 steps is 200.0
# total reward after 287 steps is 200.0
# total reward after 288 steps is 200.0
# total reward after 289 steps is 200.0
# total reward after 290 steps is 200.0
# total reward after 291 steps is 200.0
# total reward after 292 steps is 200.0
# total reward after 293 steps is 200.0
# total reward after 294 steps is 102.0
# total reward after 295 steps is 16.0
# total reward after 296 steps is 185.0
# total reward after 297 steps is 200.0
# total reward after 298 steps is 200.0
# total reward after 299 steps is 200.0
# total reward after 300 steps is 200.0
# total reward after 301 steps is 200.0
# total reward after 302 steps is 200.0
# total reward after 303 steps is 200.0
# total reward after 304 steps is 200.0
# total reward after 305 steps is 200.0
# total reward after 306 steps is 200.0
# total reward after 307 steps is 200.0
# total reward after 308 steps is 200.0
# total reward after 309 steps is 200.0
# total reward after 310 steps is 200.0
# total reward after 311 steps is 200.0
# total reward after 312 steps is 200.0
# total reward after 313 steps is 200.0
# total reward after 314 steps is 200.0
# total reward after 315 steps is 200.0
# total reward after 316 steps is 200.0
# total reward after 317 steps is 200.0
# total reward after 318 steps is 200.0
# total reward after 319 steps is 200.0
# total reward after 320 steps is 200.0
# total reward after 321 steps is 200.0
# total reward after 322 steps is 200.0
# total reward after 323 steps is 200.0
# total reward after 324 steps is 200.0
# total reward after 325 steps is 200.0
# total reward after 326 steps is 200.0
# total reward after 327 steps is 200.0
# total reward after 328 steps is 200.0
# total reward after 329 steps is 200.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-6d34988b1f4f> in <module>
#      21
#      22     if done:
# ---> 23       agentoo7.train(states, rewards, actions)
#      24       #print("total step for this episord are {}".format(t))
#      25       print("total reward after {} steps is {}".format(s, total_reward))
#
# <ipython-input-24-c61a451e8f0b> in train(self, states, rewards, actions)
#      30     for state, reward, action in zip(states, discnt_rewards, actions):
#      31       with tf.GradientTape() as tape:
# ---> 32         p = self.model(np.array([state]), training=True)
#      33         loss = self.a_loss(p, action, reward)
#      34       grads = tape.gradient(loss, self.model.trainable_variables)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# <ipython-input-23-2a6127feb2b8> in call(self, input_data)
#      11     x = self.d1(x)
#      12     x = self.d2(x)
# ---> 13     x = self.out(x)
#      14     return x
#      15
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\layers\core.py in call(self, inputs)
#    1196         self.bias,
#    1197         self.activation,
# -> 1198         dtype=self._compute_dtype_object)
#    1199
#    1200   def compute_output_shape(self, input_shape):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\layers\ops\core.py in dense(inputs, kernel, bias, activation, dtype)
#      51       outputs = sparse_ops.sparse_tensor_dense_matmul(inputs, kernel)
#      52     else:
# ---> 53       outputs = gen_math_ops.mat_mul(inputs, kernel)
#      54   # Broadcast kernel to inputs.
#      55   else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5618         _ctx._context_handle, tld.device_name, "MatMul", name,
#    5619         tld.op_callbacks, a, b, "transpose_a", transpose_a, "transpose_b",
# -> 5620         transpose_b)
#    5621       return _result
#    5622     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
